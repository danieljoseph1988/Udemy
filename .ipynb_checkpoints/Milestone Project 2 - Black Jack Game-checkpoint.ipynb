# %%
# Project Layout - Black_Jack
    # Create Card Class
        # Attributes - rank, suit, Value (result of rank & suit)
        # repr
        # Jack, King, Queen = 10; Ace - Default of 11 -> Player decides 1/11
    # Create Deck Class
        # Result of different Cards
    # Create Player Class
        # Attributes - name, balance
        # Functions
            # stand, hit, withdraw(place_bet), deposit
    # Game Mode
        # initial distribution of cards to computer (1 up/1 down) 
        # and player (both up)
        # while game on
            
            # while player_plays
            # if player decides to stand -> player_plays = False
            # if player decides to hit
                # destribute card
                # check if sum < 21
                # if card if Ace = player decision whether 1/11
            # else: player_plays = False
        # Different checks, whether computer keeps to hit cards
            # computer wins:
            # sum_computer > sum_human
            # computer keeps hitting if sum_computer < sum_human - No DRAW!
            # human wins -> sum_Human > sum_computer
            
        # if computer wins -> Money gone, if human wins -> deposit of money

# %%
#Adding global variables and imports:
import random
from IPython.display import clear_output
suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

# %%
class Card():
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[self.rank]
        
    def __repr__(self):
        return f'{self.rank} of {self.suit} with Value: {self.value}'   
    
    # Maybe add show_value and hide_value functionality to display 
    # shown card by dealer in game -> Lets see

class Deck():
    
    def __init__(self):
        self.Deck = []
    
        for suit in suits:
            for rank in ranks:
                self.Deck.append(Card(suit,rank))
    
    def shuffle(self):
        random.shuffle(self.Deck)
    
    def deal(self):
        return self.Deck.pop(0)

class Player():
    
    def __init__(self, name = "Computer", balance=0):
        self.name = name
        self.balance = balance
        self.cards = []
    
    def __repr__(self):
        return f'I am {self.name} and my current balance is: {self.balance}'
    
    def hit(self, Card):
        return self.cards.append(Card)
    
    def bet(self, amount):
        if amount > self.balance:
            print('You are out of money! Do you want to deposit?')
            return False
        self.balance -= amount
        print(f'Bet size: {amount}. Your new balance is: {self.balance}')
        return True
    
    def total_value(self):
        total = 0
        for card in self.cards:
            total += card.value
        return total
    
    def deposit(self, amount):
        self.balance += amount
        return f'Your new balance is: {self.balance}'
    
    def check_Ace(self):
        if self.cards[-1].value == 11:
            return True
        return False

# %%
def choose_Ace(Player):
    if Player.check_Ace() == True:
        print('You got an Ace! Do you want to keep it as 11 or do you want to have a 1?')
    while True:
        try:
            ace_value = int(input('11 or 1? Please type in number: '))
        except:
            print('Please type in valid number 1 or 11')
            continue
        else:
            print('Integer chosen!')
            if ace_value not in [1,11]:
                print('Please chose either 11 or 1')
                continue
            else:
                print(f'You want your Ace to be: {ace_value}')
                if ace_value == 11:
                    Player.cards[-1].value = 11
                    print(Player.total_value())
                else:
                    Player.cards[-1].value = 1
                    print(Player.total_value())
                break

def show_last_card(Player):
    print(f'{Player.name} has {Player.cards[-1].suit} of {Player.cards[-1].rank} with Value: {Player.cards[-1].value}')

# %%
Ace = Card('Hearts', 'Ace')
black_jack_deck = Deck()
black_jack_deck.shuffle()
computer = Player()
#name = input('Provide your name: ')
name = 'Daniel'
balance = int(input('Provide your amount of money: '))
human = Player(name, balance)
#print(f'Welcome {human.name}. Good luck!')

game_on = True

while game_on:
    
    print(f'Your current balance is: {human.balance}')
    #print('The next round is about to start. Please place your bet')
    bet_size = int(input('How much do you want to bet?: '))
    
    if human.bet(bet_size) == False:
        
        choice = input('Do you want to continue? Y/N: ').upper()
        if choice == 'Y':
            amount = int(input('Please choose how much money you want to deposit: '))
            human.deposit(amount)
            print(f'Your new balance is: {human.balance}')
        else:
            print('You need to go home then')
            game_on = False
            break
    
    human.cards.append(black_jack_deck.deal())
    show_last_card(human)
    if human.check_Ace() == True:
        choose_Ace(human)
        print(f'Your new Value is: {human.total_value()}')
    
    human.cards.append(black_jack_deck.deal())
    show_last_card(human)
    print(f'{human.name}. Your total value is:{human.total_value()}')
    if human.check_Ace() == True:
        choose_Ace(human)
        print(f'Your new Value is: {human.total_value()}')
    
    computer.cards.append(black_jack_deck.deal())
    print(f'{computer.name}s first card is not visible')
    computer.cards.append(black_jack_deck.deal())
    show_last_card(computer)
    
    round = True
    while round:
        print('Test')

        #Some statement about balance and question if player wants to conitnue

        round = False
    game_on = False
# Out:
# Provide your amount of money: 50
# Your current balance is: 50
# How much do you want to bet?: 10
# Bet size: 10. Your new balance is: 40
# Daniel has Spades of Four with Value: 4
# Daniel has Clubs of Queen with Value: 10
# Daniel. Your total value is:14
# Computers first card is not visible
# Computer has Diamonds of Four with Value: 4
# Test
